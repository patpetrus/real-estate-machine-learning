# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy.random import seed
seed(1)
#import tensorflow
#from sklearn.preprocessing import LabelEncoder, MinMaxScaler
#from tensorflow.keras.utils import to_categorical
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense

# %%
housing_data = pd.read_excel('finalcolumns.xlsx')
housing_data
# Out:
#              id    zip  prop_latitude  prop_longitude  prop_yrbld  \
# 0      52218838  46217      39.655831      -86.218025        2011
# 1      52713937  46268      39.874484      -86.247279        1995
# 2      51938159  46217      39.671222      -86.161665        1955
# 3      51511949  46239      39.694670      -86.013174        2006
# 4      51994006  46227      39.670611      -86.125501        1957
# ...         ...    ...            ...             ...         ...
# 17990  52503928  46202      39.795100      -86.148012        2006
# 17991  52535117  46254      39.852761      -86.249369        1990
# 17992  50847957  46219      39.786117      -86.078197        1954
# 17993  51478660  46250      39.925013      -86.049260        1987
# 17994  51546794  46278      39.891241      -86.310569        2006
#
#        prop_landsqft  prop_bldsqft  prop_livingsqft  prop_bedrms  \
# 0             6926.0        2999.0           2399.0            4
# 1            11069.0        3412.0           2350.0            4
# 2            18992.0        2796.0           2152.0            2
# 3            10759.0        4350.0           2680.0            4
# 4            13983.0        2966.0           1336.0            3
# ...              ...           ...              ...          ...
# 17990         5140.0        4344.0           2896.0            3
# 17991        12632.0        2858.0           2329.0            4
# 17992         7405.0        1808.0            904.0            2
# 17993         5009.0        1527.0           1023.0            2
# 17994        22608.0        6741.0           5400.0            4
#
#        Duration prior  duration equity  Loan Amount  starting equity  \
# 0                2231         0.203744     0.990105         0.009895
# 1                3775         0.344749     0.751880         0.248120
# 2                1214         0.110868     0.800000         0.200000
# 3                3564         0.325479     0.751881         0.248119
# 4                4891         0.446667     0.751882         0.248118
# ...               ...              ...          ...              ...
# 17990            3583         0.327215     0.751880         0.248120
# 17991            4407         0.402466     0.751880         0.248120
# 17992            1431         0.130685     0.751880         0.248120
# 17993            3173         0.289772     0.668340         0.331660
# 17994             576         0.052603     0.601479         0.398521
#
#        ending equity  price increase/decrease  Starting Rate  Ending Rate  \
# 0           0.213639                 0.122557         4.8360       4.0100
# 1           0.592869                 0.199417         6.2175       4.0100
# 2           0.310868                -0.000912         3.7100       4.5700
# 3           0.573599                -0.224450         6.5240       3.6000
# 4           0.694784                -0.122242         6.1125       3.6940
# ...              ...                      ...            ...          ...
# 17990       0.575335                 0.148407         6.6820       3.6940
# 17991       0.650586                 0.051620         7.0140       4.3375
# 17992       0.378805                 0.083484         7.9120       5.8675
# 17993       0.621432                -0.311226         6.6820       3.7100
# 17994       0.451123                -1.044542         6.2400       6.3200
#
#        Rate Difference
# 0               0.8260
# 1               2.2075
# 2              -0.8600
# 3               2.9240
# 4               2.4185
# ...                ...
# 17990           2.9880
# 17991           2.6765
# 17992           2.0445
# 17993           2.9720
# 17994          -0.0800
#
# [17995 rows x 18 columns]

# %%
housing_data = pd.get_dummies(housing_data)
housing_data
# Out:
#              id    zip  prop_latitude  prop_longitude  prop_yrbld  \
# 0      52218838  46217      39.655831      -86.218025        2011
# 1      52713937  46268      39.874484      -86.247279        1995
# 2      51938159  46217      39.671222      -86.161665        1955
# 3      51511949  46239      39.694670      -86.013174        2006
# 4      51994006  46227      39.670611      -86.125501        1957
# ...         ...    ...            ...             ...         ...
# 17990  52503928  46202      39.795100      -86.148012        2006
# 17991  52535117  46254      39.852761      -86.249369        1990
# 17992  50847957  46219      39.786117      -86.078197        1954
# 17993  51478660  46250      39.925013      -86.049260        1987
# 17994  51546794  46278      39.891241      -86.310569        2006
#
#        prop_landsqft  prop_bldsqft  prop_livingsqft  prop_bedrms  \
# 0             6926.0        2999.0           2399.0            4
# 1            11069.0        3412.0           2350.0            4
# 2            18992.0        2796.0           2152.0            2
# 3            10759.0        4350.0           2680.0            4
# 4            13983.0        2966.0           1336.0            3
# ...              ...           ...              ...          ...
# 17990         5140.0        4344.0           2896.0            3
# 17991        12632.0        2858.0           2329.0            4
# 17992         7405.0        1808.0            904.0            2
# 17993         5009.0        1527.0           1023.0            2
# 17994        22608.0        6741.0           5400.0            4
#
#        Duration prior  duration equity  Loan Amount  starting equity  \
# 0                2231         0.203744     0.990105         0.009895
# 1                3775         0.344749     0.751880         0.248120
# 2                1214         0.110868     0.800000         0.200000
# 3                3564         0.325479     0.751881         0.248119
# 4                4891         0.446667     0.751882         0.248118
# ...               ...              ...          ...              ...
# 17990            3583         0.327215     0.751880         0.248120
# 17991            4407         0.402466     0.751880         0.248120
# 17992            1431         0.130685     0.751880         0.248120
# 17993            3173         0.289772     0.668340         0.331660
# 17994             576         0.052603     0.601479         0.398521
#
#        ending equity  price increase/decrease  Starting Rate  Ending Rate  \
# 0           0.213639                 0.122557         4.8360       4.0100
# 1           0.592869                 0.199417         6.2175       4.0100
# 2           0.310868                -0.000912         3.7100       4.5700
# 3           0.573599                -0.224450         6.5240       3.6000
# 4           0.694784                -0.122242         6.1125       3.6940
# ...              ...                      ...            ...          ...
# 17990       0.575335                 0.148407         6.6820       3.6940
# 17991       0.650586                 0.051620         7.0140       4.3375
# 17992       0.378805                 0.083484         7.9120       5.8675
# 17993       0.621432                -0.311226         6.6820       3.7100
# 17994       0.451123                -1.044542         6.2400       6.3200
#
#        Rate Difference
# 0               0.8260
# 1               2.2075
# 2              -0.8600
# 3               2.9240
# 4               2.4185
# ...                ...
# 17990           2.9880
# 17991           2.6765
# 17992           2.0445
# 17993           2.9720
# 17994          -0.0800
#
# [17995 rows x 18 columns]

# %%
housing_data_dropna = housing_data.dropna()
housing_data_latlong = housing_data_dropna[['prop_latitude', 'prop_longitude']]
housing_data_dropped = housing_data_dropna.drop(columns=['prop_latitude', 'prop_longitude'])
housing_data_dropped
#housing_data_latlong
# Out:
#              id    zip  prop_yrbld  prop_landsqft  prop_bldsqft  \
# 0      52218838  46217        2011         6926.0        2999.0
# 1      52713937  46268        1995        11069.0        3412.0
# 2      51938159  46217        1955        18992.0        2796.0
# 3      51511949  46239        2006        10759.0        4350.0
# 4      51994006  46227        1957        13983.0        2966.0
# ...         ...    ...         ...            ...           ...
# 17990  52503928  46202        2006         5140.0        4344.0
# 17991  52535117  46254        1990        12632.0        2858.0
# 17992  50847957  46219        1954         7405.0        1808.0
# 17993  51478660  46250        1987         5009.0        1527.0
# 17994  51546794  46278        2006        22608.0        6741.0
#
#        prop_livingsqft  prop_bedrms  Duration prior  duration equity  \
# 0               2399.0            4            2231         0.203744
# 1               2350.0            4            3775         0.344749
# 2               2152.0            2            1214         0.110868
# 3               2680.0            4            3564         0.325479
# 4               1336.0            3            4891         0.446667
# ...                ...          ...             ...              ...
# 17990           2896.0            3            3583         0.327215
# 17991           2329.0            4            4407         0.402466
# 17992            904.0            2            1431         0.130685
# 17993           1023.0            2            3173         0.289772
# 17994           5400.0            4             576         0.052603
#
#        Loan Amount  starting equity  ending equity  price increase/decrease  \
# 0         0.990105         0.009895       0.213639                 0.122557
# 1         0.751880         0.248120       0.592869                 0.199417
# 2         0.800000         0.200000       0.310868                -0.000912
# 3         0.751881         0.248119       0.573599                -0.224450
# 4         0.751882         0.248118       0.694784                -0.122242
# ...            ...              ...            ...                      ...
# 17990     0.751880         0.248120       0.575335                 0.148407
# 17991     0.751880         0.248120       0.650586                 0.051620
# 17992     0.751880         0.248120       0.378805                 0.083484
# 17993     0.668340         0.331660       0.621432                -0.311226
# 17994     0.601479         0.398521       0.451123                -1.044542
#
#        Starting Rate  Ending Rate  Rate Difference
# 0             4.8360       4.0100           0.8260
# 1             6.2175       4.0100           2.2075
# 2             3.7100       4.5700          -0.8600
# 3             6.5240       3.6000           2.9240
# 4             6.1125       3.6940           2.4185
# ...              ...          ...              ...
# 17990         6.6820       3.6940           2.9880
# 17991         7.0140       4.3375           2.6765
# 17992         7.9120       5.8675           2.0445
# 17993         6.6820       3.7100           2.9720
# 17994         6.2400       6.3200          -0.0800
#
# [17875 rows x 16 columns]

# %%
X = housing_data_dropped[['zip', 'prop_yrbld', 'prop_landsqft', 'prop_bldsqft', 'prop_livingsqft', 'prop_bedrms', 'price increase/decrease', 'Loan Amount', 'starting equity', 'ending equity', 'Starting Rate', 'Ending Rate', 'Rate Difference']]
y = housing_data_dropped["Duration prior"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (17875, 13) (17875, 1)

# %%
df_X = pd.DataFrame(X)
df_X
# Out:
#          zip  prop_yrbld  prop_landsqft  prop_bldsqft  prop_livingsqft  \
# 0      46217        2011         6926.0        2999.0           2399.0
# 1      46268        1995        11069.0        3412.0           2350.0
# 2      46217        1955        18992.0        2796.0           2152.0
# 3      46239        2006        10759.0        4350.0           2680.0
# 4      46227        1957        13983.0        2966.0           1336.0
# ...      ...         ...            ...           ...              ...
# 17990  46202        2006         5140.0        4344.0           2896.0
# 17991  46254        1990        12632.0        2858.0           2329.0
# 17992  46219        1954         7405.0        1808.0            904.0
# 17993  46250        1987         5009.0        1527.0           1023.0
# 17994  46278        2006        22608.0        6741.0           5400.0
#
#        prop_bedrms  price increase/decrease  Loan Amount  starting equity  \
# 0                4                 0.122557     0.990105         0.009895
# 1                4                 0.199417     0.751880         0.248120
# 2                2                -0.000912     0.800000         0.200000
# 3                4                -0.224450     0.751881         0.248119
# 4                3                -0.122242     0.751882         0.248118
# ...            ...                      ...          ...              ...
# 17990            3                 0.148407     0.751880         0.248120
# 17991            4                 0.051620     0.751880         0.248120
# 17992            2                 0.083484     0.751880         0.248120
# 17993            2                -0.311226     0.668340         0.331660
# 17994            4                -1.044542     0.601479         0.398521
#
#        ending equity  Starting Rate  Ending Rate  Rate Difference
# 0           0.213639         4.8360       4.0100           0.8260
# 1           0.592869         6.2175       4.0100           2.2075
# 2           0.310868         3.7100       4.5700          -0.8600
# 3           0.573599         6.5240       3.6000           2.9240
# 4           0.694784         6.1125       3.6940           2.4185
# ...              ...            ...          ...              ...
# 17990       0.575335         6.6820       3.6940           2.9880
# 17991       0.650586         7.0140       4.3375           2.6765
# 17992       0.378805         7.9120       5.8675           2.0445
# 17993       0.621432         6.6820       3.7100           2.9720
# 17994       0.451123         6.2400       6.3200          -0.0800
#
# [17875 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train, y_train)
# Out:
# 0.9983184642651523

# %%
model.score(X_test, y_test)
# Out:
# 0.9962537233256444

# %%
# from sklearn.metrics import mean_squared_error
# MSE = mean_squared_error(y_test_scaled, predictions)
# r2 = model.score(X_test_scaled, y_test_scaled)
# print(f"MSE: {MSE}, R2: {r2}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-009bb66f5e67> in <module>
#       1 from sklearn.metrics import mean_squared_error
# ----> 2 MSE = mean_squared_error(y_test_scaled, predictions)
#       3 r2 = model.score(X_test_scaled, y_test_scaled)
#       4 print(f"MSE: {MSE}, R2: {r2}")
#
# NameError: name 'predictions' is not defined

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = ridge.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = ridge.score(X_test_scaled, y_test_scaled)


print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.0037778217578162297, R2: 0.9962539587391769

# %%
from sklearn.linear_model import ElasticNet

elasticnet = ElasticNet(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = elasticnet.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = elasticnet.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.0699056475157282, R2: 0.9306824258141152

# %%
model.predict(X_test)
# Out:
# array([[1142.48638532],
#        [1671.36837325],
#        [5950.5515631 ],
#        ...,
#        [3332.67617365],
#        [1023.14091386],
#        [ 258.37872556]])

# %%
X.shape
# Out:
# (17875, 13)

# %%
y
# Out:
# array([[2231],
#        [3775],
#        [1214],
#        ...,
#        [1431],
#        [3173],
#        [ 576]])

# %%
y.shape
# Out:
# (17875, 1)

# %%
df_y = pd.DataFrame(y)
df_y
# Out:
#           0
# 0      2231
# 1      3775
# 2      1214
# 3      3564
# 4      4891
# ...     ...
# 17870  3583
# 17871  4407
# 17872  1431
# 17873  3173
# 17874   576
#
# [17875 rows x 1 columns]

# %%
latlong_df = df_X.join(housing_data_latlong, how="outer")
latlong_df
# Out:
#          zip  prop_yrbld  prop_landsqft  prop_bldsqft  prop_livingsqft  \
# 0      46217        2011         6926.0        2999.0           2399.0
# 1      46268        1995        11069.0        3412.0           2350.0
# 2      46217        1955        18992.0        2796.0           2152.0
# 3      46239        2006        10759.0        4350.0           2680.0
# 4      46227        1957        13983.0        2966.0           1336.0
# ...      ...         ...            ...           ...              ...
# 17990  46202        2006         5140.0        4344.0           2896.0
# 17991  46254        1990        12632.0        2858.0           2329.0
# 17992  46219        1954         7405.0        1808.0            904.0
# 17993  46250        1987         5009.0        1527.0           1023.0
# 17994  46278        2006        22608.0        6741.0           5400.0
#
#        prop_bedrms  price increase/decrease  Loan Amount  starting equity  \
# 0                4                 0.122557     0.990105         0.009895
# 1                4                 0.199417     0.751880         0.248120
# 2                2                -0.000912     0.800000         0.200000
# 3                4                -0.224450     0.751881         0.248119
# 4                3                -0.122242     0.751882         0.248118
# ...            ...                      ...          ...              ...
# 17990            3                 0.148407     0.751880         0.248120
# 17991            4                 0.051620     0.751880         0.248120
# 17992            2                 0.083484     0.751880         0.248120
# 17993            2                -0.311226     0.668340         0.331660
# 17994            4                -1.044542     0.601479         0.398521
#
#        ending equity  Starting Rate  Ending Rate  Rate Difference  \
# 0           0.213639         4.8360       4.0100           0.8260
# 1           0.592869         6.2175       4.0100           2.2075
# 2           0.310868         3.7100       4.5700          -0.8600
# 3           0.573599         6.5240       3.6000           2.9240
# 4           0.694784         6.1125       3.6940           2.4185
# ...              ...            ...          ...              ...
# 17990       0.575335         6.6820       3.6940           2.9880
# 17991       0.650586         7.0140       4.3375           2.6765
# 17992       0.378805         7.9120       5.8675           2.0445
# 17993       0.621432         6.6820       3.7100           2.9720
# 17994       0.451123         6.2400       6.3200          -0.0800
#
#        prop_latitude  prop_longitude
# 0          39.655831      -86.218025
# 1          39.874484      -86.247279
# 2          39.671222      -86.161665
# 3          39.694670      -86.013174
# 4          39.670611      -86.125501
# ...              ...             ...
# 17990      39.795100      -86.148012
# 17991      39.852761      -86.249369
# 17992      39.786117      -86.078197
# 17993      39.925013      -86.049260
# 17994      39.891241      -86.310569
#
# [17875 rows x 15 columns]

# %%
appended_df = latlong_df.join(df_y, how="outer")
appended_df
# Out:
#            zip  prop_yrbld  prop_landsqft  prop_bldsqft  prop_livingsqft  \
# 0      46217.0      2011.0         6926.0        2999.0           2399.0
# 1      46268.0      1995.0        11069.0        3412.0           2350.0
# 2      46217.0      1955.0        18992.0        2796.0           2152.0
# 3      46239.0      2006.0        10759.0        4350.0           2680.0
# 4      46227.0      1957.0        13983.0        2966.0           1336.0
# ...        ...         ...            ...           ...              ...
# 17990  46202.0      2006.0         5140.0        4344.0           2896.0
# 17991  46254.0      1990.0        12632.0        2858.0           2329.0
# 17992  46219.0      1954.0         7405.0        1808.0            904.0
# 17993  46250.0      1987.0         5009.0        1527.0           1023.0
# 17994  46278.0      2006.0        22608.0        6741.0           5400.0
#
#        prop_bedrms  price increase/decrease  Loan Amount  starting equity  \
# 0              4.0                 0.122557     0.990105         0.009895
# 1              4.0                 0.199417     0.751880         0.248120
# 2              2.0                -0.000912     0.800000         0.200000
# 3              4.0                -0.224450     0.751881         0.248119
# 4              3.0                -0.122242     0.751882         0.248118
# ...            ...                      ...          ...              ...
# 17990          3.0                 0.148407     0.751880         0.248120
# 17991          4.0                 0.051620     0.751880         0.248120
# 17992          2.0                 0.083484     0.751880         0.248120
# 17993          2.0                -0.311226     0.668340         0.331660
# 17994          4.0                -1.044542     0.601479         0.398521
#
#        ending equity  Starting Rate  Ending Rate  Rate Difference  \
# 0           0.213639         4.8360       4.0100           0.8260
# 1           0.592869         6.2175       4.0100           2.2075
# 2           0.310868         3.7100       4.5700          -0.8600
# 3           0.573599         6.5240       3.6000           2.9240
# 4           0.694784         6.1125       3.6940           2.4185
# ...              ...            ...          ...              ...
# 17990       0.575335         6.6820       3.6940           2.9880
# 17991       0.650586         7.0140       4.3375           2.6765
# 17992       0.378805         7.9120       5.8675           2.0445
# 17993       0.621432         6.6820       3.7100           2.9720
# 17994       0.451123         6.2400       6.3200          -0.0800
#
#        prop_latitude  prop_longitude       0
# 0          39.655831      -86.218025  2231.0
# 1          39.874484      -86.247279  3775.0
# 2          39.671222      -86.161665  1214.0
# 3          39.694670      -86.013174  3564.0
# 4          39.670611      -86.125501  4891.0
# ...              ...             ...     ...
# 17990      39.795100      -86.148012     NaN
# 17991      39.852761      -86.249369     NaN
# 17992      39.786117      -86.078197     NaN
# 17993      39.925013      -86.049260     NaN
# 17994      39.891241      -86.310569     NaN
#
# [17995 rows x 16 columns]

# %%
appended_df_dropped = appended_df.dropna()
appended_df_dropped
# Out:
#            zip  prop_yrbld  prop_landsqft  prop_bldsqft  prop_livingsqft  \
# 0      46217.0      2011.0         6926.0        2999.0           2399.0
# 1      46268.0      1995.0        11069.0        3412.0           2350.0
# 2      46217.0      1955.0        18992.0        2796.0           2152.0
# 3      46239.0      2006.0        10759.0        4350.0           2680.0
# 4      46227.0      1957.0        13983.0        2966.0           1336.0
# ...        ...         ...            ...           ...              ...
# 17870  46219.0      1920.0         6621.0        2304.0           1560.0
# 17871  46260.0      1973.0        30305.0        8931.0           7023.0
# 17872  46237.0      2004.0         8102.0        4144.0           3564.0
# 17873  46237.0      2001.0        13373.0        5631.0           3289.0
# 17874  46224.0      1930.0         6490.0        2664.0            912.0
#
#        prop_bedrms  price increase/decrease  Loan Amount  starting equity  \
# 0              4.0                 0.122557     0.990105         0.009895
# 1              4.0                 0.199417     0.751880         0.248120
# 2              2.0                -0.000912     0.800000         0.200000
# 3              4.0                -0.224450     0.751881         0.248119
# 4              3.0                -0.122242     0.751882         0.248118
# ...            ...                      ...          ...              ...
# 17870          3.0                -0.045000     0.800000         0.200000
# 17871          5.0                 0.198718     0.800000         0.200000
# 17872          5.0                -0.201623     0.751881         0.248119
# 17873          5.0                -0.044046     0.751880         0.248120
# 17874          4.0                 0.384739     0.751880         0.248120
#
#        ending equity  Starting Rate  Ending Rate  Rate Difference  \
# 0           0.213639         4.8360        4.010           0.8260
# 1           0.592869         6.2175        4.010           2.2075
# 2           0.310868         3.7100        4.570          -0.8600
# 3           0.573599         6.5240        3.600           2.9240
# 4           0.694784         6.1125        3.694           2.4185
# ...              ...            ...          ...              ...
# 17870       0.317352         4.2550        4.010           0.2450
# 17871       0.283744         3.4600        4.265          -0.8050
# 17872       0.442457         6.0560        5.098           0.9580
# 17873       0.353326         6.1475        6.240          -0.0925
# 17874       0.423737         6.9520        6.682           0.2700
#
#        prop_latitude  prop_longitude       0
# 0          39.655831      -86.218025  2231.0
# 1          39.874484      -86.247279  3775.0
# 2          39.671222      -86.161665  1214.0
# 3          39.694670      -86.013174  3564.0
# 4          39.670611      -86.125501  4891.0
# ...              ...             ...     ...
# 17870      39.773859      -86.082128  3583.0
# 17871      39.923301      -86.169728  4407.0
# 17872      39.683539      -86.047314  1431.0
# 17873      39.642292      -86.046000  3173.0
# 17874      39.787898      -86.248322   576.0
#
# [17755 rows x 16 columns]

# %%
appended_df_dropped.to_excel('appendedfinal.xlsx', index=False)

# %%
model.score(X,y)
# Out:
# 0.9977989895170936

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[-1.46967043e-02 -3.65930518e-02 -6.67155235e-09 -1.62199307e-03
#    7.62561410e-04 -5.61179321e-01  2.10134486e-03  5.46174721e+03
#   -5.46174721e+03  1.09252337e+04  2.25326599e-01 -1.35259798e+00
#    1.57792458e+00]]
# y-axis intercept:  [-4696.39012878]

# %%
np.array([X.min()]).shape
# Out:
# (1, 13)

# %%
X.min()
# Out:
# zip                        46201.000000
# prop_yrbld                  1900.000000
# prop_landsqft                436.000000
# prop_bldsqft                 462.000000
# prop_livingsqft              431.000000
# prop_bedrms                    1.000000
# price increase/decrease    -2987.020751
# Loan Amount                    0.000000
# starting equity              -83.361133
# ending equity                -83.346795
# Starting Rate                  3.345000
# Ending Rate                    3.232500
# Rate Difference               -1.532500
# dtype: float64

# %%
x_min = np.array([X.min()])
x_max = np.array([X.max()])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[ 4.62010000e+04  1.90000000e+03  4.36000000e+02  4.62000000e+02
#    4.31000000e+02  1.00000000e+00 -2.98702075e+03  0.00000000e+00
#   -8.33611331e+01 -8.33467952e+01  3.34500000e+00  3.23250000e+00
#   -1.53250000e+00]]
# Max X Value: [[4.62900000e+04 2.01700000e+03 4.32629512e+08 2.50040000e+04
#   1.30340000e+04 9.00000000e+00 9.58841197e-01 8.43611331e+01
#   1.00000000e+00 1.69031963e+00 1.27087500e+01 8.02750000e+00
#   6.67125000e+00]]

# %%
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
x_min.shape, x_max.shape, y_min.shape, y_max.shape, X.shape, y.shape
# Out:
# ((1, 13), (1, 13), (1, 1), (1, 1), (17875, 13), (17875, 1))

# %%
X
# Out:
#          zip  prop_yrbld  prop_landsqft  prop_bldsqft  prop_livingsqft  \
# 0      46217        2011         6926.0        2999.0           2399.0
# 1      46268        1995        11069.0        3412.0           2350.0
# 2      46217        1955        18992.0        2796.0           2152.0
# 3      46239        2006        10759.0        4350.0           2680.0
# 4      46227        1957        13983.0        2966.0           1336.0
# ...      ...         ...            ...           ...              ...
# 17990  46202        2006         5140.0        4344.0           2896.0
# 17991  46254        1990        12632.0        2858.0           2329.0
# 17992  46219        1954         7405.0        1808.0            904.0
# 17993  46250        1987         5009.0        1527.0           1023.0
# 17994  46278        2006        22608.0        6741.0           5400.0
#
#        prop_bedrms  price increase/decrease  Loan Amount  starting equity  \
# 0                4                 0.122557     0.990105         0.009895
# 1                4                 0.199417     0.751880         0.248120
# 2                2                -0.000912     0.800000         0.200000
# 3                4                -0.224450     0.751881         0.248119
# 4                3                -0.122242     0.751882         0.248118
# ...            ...                      ...          ...              ...
# 17990            3                 0.148407     0.751880         0.248120
# 17991            4                 0.051620     0.751880         0.248120
# 17992            2                 0.083484     0.751880         0.248120
# 17993            2                -0.311226     0.668340         0.331660
# 17994            4                -1.044542     0.601479         0.398521
#
#        ending equity  Starting Rate  Ending Rate  Rate Difference
# 0           0.213639         4.8360       4.0100           0.8260
# 1           0.592869         6.2175       4.0100           2.2075
# 2           0.310868         3.7100       4.5700          -0.8600
# 3           0.573599         6.5240       3.6000           2.9240
# 4           0.694784         6.1125       3.6940           2.4185
# ...              ...            ...          ...              ...
# 17990       0.575335         6.6820       3.6940           2.9880
# 17991       0.650586         7.0140       4.3375           2.6765
# 17992       0.378805         7.9120       5.8675           2.0445
# 17993       0.621432         6.6820       3.7100           2.9720
# 17994       0.451123         6.2400       6.3200          -0.0800
#
# [17875 rows x 13 columns]

# %%
x_min[:,1]
# Out:
# array([1900.])

# %%
plt.scatter(X[["ending equity"]], y, c='blue')
#plt.plot([x_min[:,12], x_max[:,12]], [y_min[0], y_max[0]], c='red')

# %%
import pickle

# %%
filename = 'finalized_model1.csv'
pickle.dump(model, open(filename, 'wb'))

# %%
model.coef_
# Out:
# array([[-1.46967043e-02, -3.65930518e-02, -6.67155235e-09,
#         -1.62199307e-03,  7.62561410e-04, -5.61179321e-01,
#          2.10134486e-03,  5.46174721e+03, -5.46174721e+03,
#          1.09252337e+04,  2.25326599e-01, -1.35259798e+00,
#          1.57792458e+00]])

# %%
X.columns
# Out:
# Index(['zip', 'prop_yrbld', 'prop_landsqft', 'prop_bldsqft', 'prop_livingsqft',
#        'prop_bedrms', 'price increase/decrease', 'Loan Amount',
#        'starting equity', 'ending equity', 'Starting Rate', 'Ending Rate',
#        'Rate Difference'],
#       dtype='object')

# %%
coef,col = list(model.coef_),list(X.columns)

# %%
print(list(zip(model.coef_, list(X.columns))))
# Out:
# [(array([-1.46967043e-02, -3.65930518e-02, -6.67155235e-09, -1.62199307e-03,
#         7.62561410e-04, -5.61179321e-01,  2.10134486e-03,  5.46174721e+03,
#        -5.46174721e+03,  1.09252337e+04,  2.25326599e-01, -1.35259798e+00,
#         1.57792458e+00]), 'zip')]

# %%
result = zip(coef[0],col)
#print(list(result))
for elem in result:
       print(elem)
# Out:
# (-0.014696704301602716, 'zip')
# (-0.036593051832993384, 'prop_yrbld')
# (-6.671552349748813e-09, 'prop_landsqft')
# (-0.0016219930739201634, 'prop_bldsqft')
# (0.0007625614098215509, 'prop_livingsqft')
# (-0.5611793206557806, 'prop_bedrms')
# (0.00210134485838423, 'price increase/decrease')
# (5461.747206951571, 'Loan Amount')
# (-5461.74720695158, 'starting equity')
# (10925.233746543374, 'ending equity')
# (0.22532659897781782, 'Starting Rate')
# (-1.3525979846817289, 'Ending Rate')
# (1.5779245836810782, 'Rate Difference')

# %%
type(result)
# Out:
# zip

# %%
len(coef[0]),len(col)
# Out:
# (13, 13)

# %%
coef[0]
# Out:
# array([-1.46967043e-02, -3.65930518e-02, -6.67155235e-09, -1.62199307e-03,
#         7.62561410e-04, -5.61179321e-01,  2.10134486e-03,  5.46174721e+03,
#        -5.46174721e+03,  1.09252337e+04,  2.25326599e-01, -1.35259798e+00,
#         1.57792458e+00])

# %%
y_test_scaled
# Out:
# array([[-0.73021026],
#        [-0.39213833],
#        [ 2.36192678],
#        ...,
#        [ 0.67542343],
#        [-0.80862238],
#        [-1.30223312]])

# %%
y
# Out:
# array([[2231],
#        [3775],
#        [1214],
#        ...,
#        [1431],
#        [3173],
#        [ 576]])
